# %%
import pandas as pd

# %%
df=pd.read_csv("../data/census2011.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4cdae4bfc141> in <module>()
# ----> 1 df=pd.read_csv("../data/census2011.csv")
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#         Person ID     Region Residence Type  Family Composition  \
# 0         7394816  E12000001              H                   2
# 1         7394745  E12000001              H                   5
# 2         7395066  E12000001              H                   3
# 3         7395329  E12000001              H                   3
# 4         7394712  E12000001              H                   3
# 5         7394750  E12000001              H                   2
# 6         7394871  E12000001              H                   5
# 7         7394832  E12000001              H                   3
# 8         7394719  E12000001              H                   2
# 9         7394840  E12000001              H                   1
# 10        7394510  E12000001              H                   1
# 11        7394711  E12000001              H                   2
# 12        7395070  E12000001              H                   1
# 13        7394869  E12000001              H                   1
# ...

# %%
len(df)
# Out:
# 569741

# %%
df.dtypes
# Out:
# Person ID                     int64
# Region                       object
# Residence Type               object
# Family Composition            int64
# Population Base               int64
# Sex                           int64
# Age                           int64
# Marital Status                int64
# Student                       int64
# Country of Birth              int64
# Health                        int64
# Ethnic Group                  int64
# Religion                      int64
# Economic Activity             int64
# Occupation                    int64
# Industry                      int64
# Hours worked per week         int64
# Approximated Social Grade     int64
# dtype: object
